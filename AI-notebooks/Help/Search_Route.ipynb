# %% [markdown]
# # Lab 2. Search
# # Task 2.1 Route Planning
# ## Problem Descriptions
# implement a programme for route programming.
# ## Implementation and Results
# in route planning we try to find a suitable route to travel all the given cities give in statement or available to traverse.
#
# we define the following states of problem:-
#
# 1. State: number 1 to 6 for the cities
# 2. Action: travelling from one city to other
# 3. Goal test: check for detination
# 4. Path cost: This is given is the graph. We transform it into a 6x6 array whose
# elements are the distance between a pair of cities (0 for self and ‘inf’ for
# unconnected).

# %%
# !pip install simpleai
from simpleai.search import SearchProblem, astar, greedy, breadth_first, depth_first, uniform_cost
import math
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.4/94.4 KB 11.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for simpleai: filename=simpleai-0.8.3-py3-none-any.whl size=101000 sha256=b1e2a922e61aabae308c5fd98642806918982c3d4e04845b4992adaf86acdd43
#   Stored in directory: /root/.cache/pip/wheels/5d/2d/67/00b435b82fb8b17a0835aa94f2c614a6dd4b375837c0071be0
# Successfully built simpleai
# ...

# %%
COSTS = [
    [0, 7, 9, 'inf', 'inf', 14],
    [7, 0, 10, 15, 'inf', 'inf'],
    [9, 10, 0, 11, 'inf', 2],
    ['inf', 15, 11, 0, 6, 'inf'],
    ['inf', 'inf', 'inf', 6, 0, 9],
    [14, 'inf', 2, 'inf', 9, 0]
]

# %%
class Route(SearchProblem):

    # initialise with the initial and goal states. Do "-1" because the nodes start from 1.
    def __init__(self, initial, goal):
        self.initial = initial-1
        self.goal = goal-1
        super(Route, self).__init__(initial_state=self.initial)

    # add all connected nodes, i.e. those with a cost of not 0 or inf
    def actions(self, state):
        actions = []
        for action in range(len(COSTS[state])):
            if COSTS[state][action] not in ['inf', 0]:
                actions.append(action)
        return actions

    # the result state is just the action as defined
    def result(self, state, action):
        return action

    # check if goal is reached
    def is_goal(self, state):
        return state == self.goal

    # return the cost between two states
    def cost(self, state, action, state2):
        return COSTS[state][action]

# %%
problem = Route(1, 5)
# result = breadth_first(problem, graph_search=True)
# result = depth_first(problem, graph_search=True)
result = uniform_cost(problem)

# Print the results
path = [x[1]+1 for x in result.path()] 
print("The route is %s, and total cost is %s" %(path, result.cost))
# Out:
# The route is [1, 3, 6, 5], and total cost is 20

# %%
problem = Route(1, 5)
result = breadth_first(problem, graph_search=True)


# Print the results
path = [x[1]+1 for x in result.path()] 
print("The route is %s, and total cost is %s" %(path, result.cost))
# Out:
# The route is [1, 6, 5], and total cost is 23

# %%
problem = Route(1, 5)

result = depth_first(problem, graph_search=True)


# Print the results
path = [x[1]+1 for x in result.path()] 
print("The route is %s, and total cost is %s" %(path, result.cost))
# Out:
# The route is [1, 6, 5], and total cost is 23

# %% [markdown]
# ## Discussions
#
# we are trying to find the best route:-
#
# best route in three algorithms are as follows:--
# * BFS : Breadth-first search (BFS) is an algorithm for searching a tree data structure for a node that satisfies a given property. It starts at the tree root and explores all nodes at the present depth prior to moving on to the nodes at the next depth level. (wikipedia)
#
#    The route is [1, 6, 5], and total cost is 23.
#
# * UCS: Uniform-cost search is an uninformed search algorithm that uses the lowest cumulative cost to find a path from the source to the destination. Nodes are expanded, starting from the root, according to the minimum cumulative cost.(https://www.educative.io/)
#
#     The route is [1, 3, 6, 5], and total cost is 20
# * DFS : Depth-first search (DFS) is an algorithm for traversing or searching tree or graph data structures. The algorithm starts at the root node (selecting some arbitrary node as the root node in the case of a graph) and explores as far as possible along each branch before backtracking. Extra memory, usually a stack, is needed to keep track of the nodes discovered so far along a specified branch which helps in backtracking of the graph.(wikipedia)
#
#    The route is [1, 6, 5], and total cost is 23
