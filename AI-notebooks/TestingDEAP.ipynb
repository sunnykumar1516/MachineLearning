# %%
# !pip install deap
import random

from deap import base
from deap import creator
from deap import tools
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting deap
#   Downloading deap-1.3.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (139 kB)
#      |████████████████████████████████| 139 kB 7.9 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from deap) (1.21.6)
# Installing collected packages: deap
# Successfully installed deap-1.3.3

# %%
IND_SIZE = 5

creator.create("FitnessMin", base.Fitness, weights=(-1.0, -1.0))
creator.create("Individual", list, fitness=creator.FitnessMin)

toolbox = base.Toolbox()
toolbox.register("attr_float", random.random)
toolbox.register("individual", tools.initRepeat, creator.Individual,
                 toolbox.attr_float, n=IND_SIZE)

# %%
ind1 = toolbox.individual()

# %%
print(ind1)               # [0.86..., 0.27..., 0.70..., 0.03..., 0.87...]
print(ind1.fitness.valid)
# Out:
# [0.4664086478933568, 0.07937968352258762, 0.20548561707878465, 0.659561894347736, 0.5151444214770875]
# False

# %%
pip install pyeasyga
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyeasyga
#   Downloading pyeasyga-0.3.1.tar.gz (20 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from pyeasyga) (1.15.0)
# Building wheels for collected packages: pyeasyga
#   Building wheel for pyeasyga (setup.py) ... done
#   Created wheel for pyeasyga: filename=pyeasyga-0.3.1-py2.py3-none-any.whl size=6806 sha256=266fd266cf0fb58fb582ebcee33a89e93403ca56ad6d77da853264b60c5cc3e1
#   Stored in directory: /root/.cache/pip/wheels/58/fa/2a/493c9d613e1048d4338ce44436a2e1c056b9ffcc75fb79add5
# Successfully built pyeasyga
# Installing collected packages: pyeasyga
# Successfully installed pyeasyga-0.3.1
